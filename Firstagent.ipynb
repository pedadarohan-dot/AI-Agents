# %% [markdown]
# <a href="https://colab.research.google.com/github/pedadarohan-dot/AI-Agents/blob/main/Firstagent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google-adk

# %%
import os
from google.colab import userdata

try:
    GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %%
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types
print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %% [markdown]
# We have build our agent with it's properties name, model, description and instuction(prompt)

# %%
import os

api_key_value = userdata.get('GOOGLE_API_KEY')
print(f"API Key value being used: {api_key_value}")

os.environ["GOOGLE_API_KEY"] = api_key_value # Set as environment variable

root_agent = Agent(
    name="helpful_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        # api_key=api_key_value, # Removed as setting env var should suffice
        retry_options=retry_config
    ),
    description="A simple agent that can answer general questions.",
    instruction="You are a helpful assistant. Use Google Search for current info or if unsure.",
    tools=[google_search],
)

print("✅ Root Agent defined.")
# Out:
# API Key value being used: AIzaSyC4qhfWL_fDkhXL4wjRf4hzKnVBNlf7Qe0
# ✅ Root Agent defined.

# %% [markdown]
# We have created a runner to run the agent

# %%
runner = InMemoryRunner(agent=root_agent)

print("✅ Runner created.")
# Out:
# ✅ Runner created.

# %% [markdown]
# Now you can call the .run_debug() method to send our prompt and get an answer.

# %%
response = await runner.run_debug(
    "What is Agent Development Kit from Google? What languages is the SDK available in?"
)
print(response)
# Out:
#  ### Created new session: debug_session_id
#
# User > What is Agent Development Kit from Google? What languages is the SDK available in?
# helpful_assistant > The Google Agent Development Kit (ADK) is an open-source, flexible, and modular framework designed to simplify the development, deployment, and orchestration of AI agents. It aims to make agent development feel more akin to traditional software development, offering developers greater control and testability. ADK is optimized for Google's AI offerings, like Gemini and Vertex AI, but is model-agnostic and compatible with other frameworks. It supports the creation of complex workflows and multi-agent systems through a code-first approach.
#
# The SDK is available in the following programming languages:
#
# *   **Python**
# *   **TypeScript**
# *   **Go**
# *   **Java**
# [Event(model_version='gemini-2.5-flash-lite', content=Content(
#   parts=[
#     Part(
# ...

# %%
response = await runner.run_debug("What's the weather in London?")
# Out:
#  ### Continue session: debug_session_id
#
# User > What's the weather in London?
# helpful_assistant > The weather in London is currently mostly cloudy with a temperature of 38°F (3°C). The humidity is around 83%.
#
# Here's a look at the forecast for the next few days:
# *   **Thursday, January 1, 2026:** Cloudy during the day and at night. There's a 10% chance of snow during the day and a 20% chance of rain at night. Temperatures will range between 34°F (1°C) and 42°F (6°C).
# *   **Friday, January 2, 2026:** Sunny during the day and clear at night, with a 15% chance of snow during the day. Temperatures will be between 30°F (-1°C) and 39°F (4°C).
# *   **Saturday, January 3, 2026:** Sunny during the day and clear at night, with temperatures between 27°F (-3°C) and 36°F (2°C).
